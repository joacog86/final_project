# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st

pd.set_option('display.max_columns', None)

# %%
# Loading the dataset

main_file = pd.read_excel('../data/raw/Telco_customer_churn.xlsx')

# %%
# Initial Exploration

main_file.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# 0      No         No              2           Yes             No
# 1      No        Yes              2           Yes             No
# 2      No        Yes              8           Yes            Yes
# 3     Yes        Yes             28           Yes            Yes
# 4      No        Yes             49           Yes            Yes
#
#   Internet Service Online Security Online Backup Device Protection  \
# 0              DSL             Yes           Yes                No
# 1      Fiber optic              No            No                No
# 2      Fiber optic              No            No               Yes
# 3      Fiber optic              No            No               Yes
# 4      Fiber optic              No           Yes               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# 0           No           No               No  Month-to-month
# 1           No           No               No  Month-to-month
# 2           No          Yes              Yes  Month-to-month
# 3          Yes          Yes              Yes  Month-to-month
# 4           No          Yes              Yes  Month-to-month
#
#   Paperless Billing             Payment Method  Monthly Charges Total Charges  \
# 0               Yes               Mailed check            53.85        108.15
# 1               Yes           Electronic check            70.70        151.65
# 2               Yes           Electronic check            99.65         820.5
# 3               Yes           Electronic check           104.80       3046.05
# 4               Yes  Bank transfer (automatic)           103.70        5036.3
#
#   Churn Label  Churn Value  Churn Score  CLTV                   Churn Reason
# 0         Yes            1           86  3239   Competitor made better offer
# 1         Yes            1           67  2701                          Moved
# 2         Yes            1           86  5372                          Moved
# 3         Yes            1           84  5003                          Moved
# 4         Yes            1           89  5340  Competitor had better devices

# %%
main_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
#  16  Internet Service   7043 non-null   object
#  17  Online Security    7043 non-null   object
#  18  Online Backup      7043 non-null   object
#  19  Device Protection  7043 non-null   object
#  20  Tech Support       7043 non-null   object
#  21  Streaming TV       7043 non-null   object
#  22  Streaming Movies   7043 non-null   object
#  23  Contract           7043 non-null   object
#  24  Paperless Billing  7043 non-null   object
#  25  Payment Method     7043 non-null   object
#  26  Monthly Charges    7043 non-null   float64
#  27  Total Charges      7043 non-null   object
#  28  Churn Label        7043 non-null   object
#  29  Churn Value        7043 non-null   int64
#  30  Churn Score        7043 non-null   int64
#  31  CLTV               7043 non-null   int64
#  32  Churn Reason       1869 non-null   object
# dtypes: float64(3), int64(6), object(24)
# memory usage: 1.8+ MB

# %% [markdown]
# ## Merging multiple excels

# %%
demographics_file = pd.read_excel('../data/raw/Telco_customer_churn_demographics.xlsx')
churn_status_file = pd.read_excel('../data/raw/Telco_customer_churn_status.xlsx')
services_file = pd.read_excel('../data/raw/Telco_customer_churn_services.xlsx') 

# Merge DataFrames based on the common key
data = pd.merge(main_file, demographics_file, on='CustomerID', how='outer',suffixes=('','_x'))

# Display the result DataFrame
data.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# 0      No         No              2           Yes             No
# 1      No        Yes              2           Yes             No
# 2      No        Yes              8           Yes            Yes
# 3     Yes        Yes             28           Yes            Yes
# 4      No        Yes             49           Yes            Yes
#
#   Internet Service Online Security Online Backup Device Protection  \
# 0              DSL             Yes           Yes                No
# 1      Fiber optic              No            No                No
# 2      Fiber optic              No            No               Yes
# 3      Fiber optic              No            No               Yes
# 4      Fiber optic              No           Yes               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# 0           No           No               No  Month-to-month
# 1           No           No               No  Month-to-month
# 2           No          Yes              Yes  Month-to-month
# 3          Yes          Yes              Yes  Month-to-month
# 4           No          Yes              Yes  Month-to-month
#
#   Paperless Billing             Payment Method  Monthly Charges Total Charges  \
# 0               Yes               Mailed check            53.85        108.15
# 1               Yes           Electronic check            70.70        151.65
# 2               Yes           Electronic check            99.65         820.5
# 3               Yes           Electronic check           104.80       3046.05
# 4               Yes  Bank transfer (automatic)           103.70        5036.3
#
#   Churn Label  Churn Value  Churn Score  CLTV                   Churn Reason  \
# 0         Yes            1           86  3239   Competitor made better offer
# 1         Yes            1           67  2701                          Moved
# 2         Yes            1           86  5372                          Moved
# 3         Yes            1           84  5003                          Moved
# 4         Yes            1           89  5340  Competitor had better devices
#
#    Count_x Gender_x  Age Under 30 Senior Citizen_x Married Dependents_x  \
# 0        1     Male   37       No               No      No           No
# 1        1   Female   19      Yes               No      No          Yes
# 2        1   Female   31       No               No      No          Yes
# 3        1   Female   23      Yes               No     Yes          Yes
# 4        1     Male   38       No               No      No          Yes
#
#    Number of Dependents
# 0                     0
# 1                     2
# 2                     2
# 3                     3
# 4                     1

# %%
# Drop duplicated columns that have a _x in its name
selected_columns_x = data.filter(regex='_x$', axis=1)
data = data.drop(columns=selected_columns_x)

# %%
# Merged the next dataset
data = pd.merge(data, churn_status_file, on='CustomerID', how='outer',suffixes=('','_x'))
data.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# 0      No         No              2           Yes             No
# 1      No        Yes              2           Yes             No
# 2      No        Yes              8           Yes            Yes
# 3     Yes        Yes             28           Yes            Yes
# 4      No        Yes             49           Yes            Yes
#
#   Internet Service Online Security Online Backup Device Protection  \
# 0              DSL             Yes           Yes                No
# 1      Fiber optic              No            No                No
# 2      Fiber optic              No            No               Yes
# 3      Fiber optic              No            No               Yes
# 4      Fiber optic              No           Yes               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# 0           No           No               No  Month-to-month
# 1           No           No               No  Month-to-month
# 2           No          Yes              Yes  Month-to-month
# 3          Yes          Yes              Yes  Month-to-month
# 4           No          Yes              Yes  Month-to-month
#
#   Paperless Billing             Payment Method  Monthly Charges Total Charges  \
# 0               Yes               Mailed check            53.85        108.15
# 1               Yes           Electronic check            70.70        151.65
# 2               Yes           Electronic check            99.65         820.5
# 3               Yes           Electronic check           104.80       3046.05
# 4               Yes  Bank transfer (automatic)           103.70        5036.3
#
#   Churn Label  Churn Value  Churn Score  CLTV                   Churn Reason  \
# 0         Yes            1           86  3239   Competitor made better offer
# 1         Yes            1           67  2701                          Moved
# 2         Yes            1           86  5372                          Moved
# 3         Yes            1           84  5003                          Moved
# 4         Yes            1           89  5340  Competitor had better devices
#
#    Age Under 30 Married  Number of Dependents  Satisfaction Score  \
# 0   37       No      No                     0                   1
# 1   19      Yes      No                     2                   2
# 2   31       No      No                     2                   3
# 3   23      Yes     Yes                     3                   3
# 4   38       No      No                     1                   1
#
#   Customer Status Churn Label_x  Churn Value_x  Churn Score_x  CLTV_x  \
# 0         Churned           Yes              1             86    3239
# 1         Churned           Yes              1             67    2701
# 2         Churned           Yes              1             86    5372
# 3         Churned           Yes              1             84    5003
# 4         Churned           Yes              1             89    5340
#
#                   Churn Reason_x
# 0   Competitor made better offer
# 1                          Moved
# 2                          Moved
# 3                          Moved
# 4  Competitor had better devices

# %%
#Drop
selected_columns_x = data.filter(regex='_x$', axis=1)
data = data.drop(columns=selected_columns_x)

# %%
#Merge
data = pd.merge(data, services_file, on='CustomerID', how='outer',suffixes=('','_x'))
data.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# 0      No         No              2           Yes             No
# 1      No        Yes              2           Yes             No
# 2      No        Yes              8           Yes            Yes
# 3     Yes        Yes             28           Yes            Yes
# 4      No        Yes             49           Yes            Yes
#
#   Internet Service Online Security Online Backup Device Protection  \
# 0              DSL             Yes           Yes                No
# 1      Fiber optic              No            No                No
# 2      Fiber optic              No            No               Yes
# 3      Fiber optic              No            No               Yes
# 4      Fiber optic              No           Yes               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# 0           No           No               No  Month-to-month
# 1           No           No               No  Month-to-month
# 2           No          Yes              Yes  Month-to-month
# 3          Yes          Yes              Yes  Month-to-month
# 4           No          Yes              Yes  Month-to-month
#
#   Paperless Billing             Payment Method  Monthly Charges Total Charges  \
# 0               Yes               Mailed check            53.85        108.15
# 1               Yes           Electronic check            70.70        151.65
# 2               Yes           Electronic check            99.65         820.5
# 3               Yes           Electronic check           104.80       3046.05
# 4               Yes  Bank transfer (automatic)           103.70        5036.3
#
#   Churn Label  Churn Value  Churn Score  CLTV                   Churn Reason  \
# 0         Yes            1           86  3239   Competitor made better offer
# 1         Yes            1           67  2701                          Moved
# 2         Yes            1           86  5372                          Moved
# 3         Yes            1           84  5003                          Moved
# 4         Yes            1           89  5340  Competitor had better devices
#
#    Age Under 30 Married  Number of Dependents  Satisfaction Score  \
# 0   37       No      No                     0                   1
# 1   19      Yes      No                     2                   2
# 2   31       No      No                     2                   3
# 3   23      Yes     Yes                     3                   3
# 4   38       No      No                     1                   1
#
#   Customer Status  Count_x Quarter Referred a Friend  Number of Referrals  \
# 0         Churned        1      Q3                No                    0
# 1         Churned        1      Q3                No                    0
# 2         Churned        1      Q3                No                    0
# 3         Churned        1      Q3                No                    0
# 4         Churned        1      Q3                No                    0
#
#    Tenure in Months    Offer Phone Service_x  \
# 0                 2      NaN             Yes
# 1                 2      NaN             Yes
# 2                 8      NaN             Yes
# 3                28  Offer C             Yes
# 4                49      NaN             Yes
#
#    Avg Monthly Long Distance Charges Multiple Lines_x Internet Service_x  \
# 0                              10.47               No                Yes
# 1                               9.12               No                Yes
# 2                              12.15              Yes                Yes
# 3                               4.89              Yes                Yes
# 4                              44.33              Yes                Yes
#
#   Internet Type  Avg Monthly GB Download Online Security_x Online Backup_x  \
# 0           DSL                       21               Yes             Yes
# 1   Fiber Optic                       51                No              No
# 2         Cable                       26                No              No
# 3   Fiber Optic                       47                No              No
# 4   Fiber Optic                       11                No             Yes
#
#   Device Protection Plan Premium Tech Support Streaming TV_x  \
# 0                     No                   No             No
# 1                     No                   No             No
# 2                    Yes                   No            Yes
# 3                    Yes                  Yes            Yes
# 4                    Yes                   No            Yes
#
#   Streaming Movies_x Streaming Music Unlimited Data      Contract_x  \
# 0                 No              No            Yes  Month-to-Month
# 1                 No              No            Yes  Month-to-Month
# 2                Yes             Yes            Yes  Month-to-Month
# 3                Yes             Yes            Yes  Month-to-Month
# 4                Yes             Yes            Yes  Month-to-Month
#
#   Paperless Billing_x Payment Method_x  Monthly Charge  Total Charges_x  \
# 0                 Yes      Credit Card           53.85           108.15
# 1                 Yes  Bank Withdrawal           70.70           151.65
# 2                 Yes  Bank Withdrawal           99.65           820.50
# 3                 Yes  Bank Withdrawal          104.80          3046.05
# 4                 Yes  Bank Withdrawal          103.70          5036.30
#
#    Total Refunds  Total Extra Data Charges  Total Long Distance Charges  \
# 0            0.0                         0                        20.94
# 1            0.0                         0                        18.24
# 2            0.0                         0                        97.20
# 3            0.0                         0                       136.92
# 4            0.0                         0                      2172.17
#
#    Total Revenue
# 0         129.09
# 1         169.89
# 2         917.70
# 3        3182.97
# 4        7208.47

# %%
#Drop
selected_columns_x = data.filter(regex='_x$', axis=1)
data = data.drop(columns=selected_columns_x)

# %%
#Final dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 56 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   CustomerID                         7043 non-null   object
#  1   Count                              7043 non-null   int64
#  2   Country                            7043 non-null   object
#  3   State                              7043 non-null   object
#  4   City                               7043 non-null   object
#  5   Zip Code                           7043 non-null   int64
#  6   Lat Long                           7043 non-null   object
#  7   Latitude                           7043 non-null   float64
#  8   Longitude                          7043 non-null   float64
#  9   Gender                             7043 non-null   object
#  10  Senior Citizen                     7043 non-null   object
#  11  Partner                            7043 non-null   object
#  12  Dependents                         7043 non-null   object
#  13  Tenure Months                      7043 non-null   int64
#  14  Phone Service                      7043 non-null   object
#  15  Multiple Lines                     7043 non-null   object
#  16  Internet Service                   7043 non-null   object
#  17  Online Security                    7043 non-null   object
#  18  Online Backup                      7043 non-null   object
#  19  Device Protection                  7043 non-null   object
#  20  Tech Support                       7043 non-null   object
#  21  Streaming TV                       7043 non-null   object
#  22  Streaming Movies                   7043 non-null   object
#  23  Contract                           7043 non-null   object
#  24  Paperless Billing                  7043 non-null   object
#  25  Payment Method                     7043 non-null   object
#  26  Monthly Charges                    7043 non-null   float64
#  27  Total Charges                      7043 non-null   object
#  28  Churn Label                        7043 non-null   object
#  29  Churn Value                        7043 non-null   int64
#  30  Churn Score                        7043 non-null   int64
#  31  CLTV                               7043 non-null   int64
#  32  Churn Reason                       1869 non-null   object
#  33  Age                                7043 non-null   int64
#  34  Under 30                           7043 non-null   object
#  35  Married                            7043 non-null   object
#  36  Number of Dependents               7043 non-null   int64
#  37  Satisfaction Score                 7043 non-null   int64
#  38  Customer Status                    7043 non-null   object
#  39  Quarter                            7043 non-null   object
#  40  Referred a Friend                  7043 non-null   object
#  41  Number of Referrals                7043 non-null   int64
#  42  Tenure in Months                   7043 non-null   int64
#  43  Offer                              3166 non-null   object
#  44  Avg Monthly Long Distance Charges  7043 non-null   float64
#  45  Internet Type                      5517 non-null   object
#  46  Avg Monthly GB Download            7043 non-null   int64
#  47  Device Protection Plan             7043 non-null   object
#  48  Premium Tech Support               7043 non-null   object
#  49  Streaming Music                    7043 non-null   object
#  50  Unlimited Data                     7043 non-null   object
#  51  Monthly Charge                     7043 non-null   float64
#  52  Total Refunds                      7043 non-null   float64
#  53  Total Extra Data Charges           7043 non-null   int64
#  54  Total Long Distance Charges        7043 non-null   float64
#  55  Total Revenue                      7043 non-null   float64
# dtypes: float64(8), int64(13), object(35)
# memory usage: 3.0+ MB

# %%
data.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# 0      No         No              2           Yes             No
# 1      No        Yes              2           Yes             No
# 2      No        Yes              8           Yes            Yes
# 3     Yes        Yes             28           Yes            Yes
# 4      No        Yes             49           Yes            Yes
#
#   Internet Service Online Security Online Backup Device Protection  \
# 0              DSL             Yes           Yes                No
# 1      Fiber optic              No            No                No
# 2      Fiber optic              No            No               Yes
# 3      Fiber optic              No            No               Yes
# 4      Fiber optic              No           Yes               Yes
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# 0           No           No               No  Month-to-month
# 1           No           No               No  Month-to-month
# 2           No          Yes              Yes  Month-to-month
# 3          Yes          Yes              Yes  Month-to-month
# 4           No          Yes              Yes  Month-to-month
#
#   Paperless Billing             Payment Method  Monthly Charges Total Charges  \
# 0               Yes               Mailed check            53.85        108.15
# 1               Yes           Electronic check            70.70        151.65
# 2               Yes           Electronic check            99.65         820.5
# 3               Yes           Electronic check           104.80       3046.05
# 4               Yes  Bank transfer (automatic)           103.70        5036.3
#
#   Churn Label  Churn Value  Churn Score  CLTV                   Churn Reason  \
# 0         Yes            1           86  3239   Competitor made better offer
# 1         Yes            1           67  2701                          Moved
# 2         Yes            1           86  5372                          Moved
# 3         Yes            1           84  5003                          Moved
# 4         Yes            1           89  5340  Competitor had better devices
#
#    Age Under 30 Married  Number of Dependents  Satisfaction Score  \
# 0   37       No      No                     0                   1
# 1   19      Yes      No                     2                   2
# 2   31       No      No                     2                   3
# 3   23      Yes     Yes                     3                   3
# 4   38       No      No                     1                   1
#
#   Customer Status Quarter Referred a Friend  Number of Referrals  \
# 0         Churned      Q3                No                    0
# 1         Churned      Q3                No                    0
# 2         Churned      Q3                No                    0
# 3         Churned      Q3                No                    0
# 4         Churned      Q3                No                    0
#
#    Tenure in Months    Offer  Avg Monthly Long Distance Charges Internet Type  \
# 0                 2      NaN                              10.47           DSL
# 1                 2      NaN                               9.12   Fiber Optic
# 2                 8      NaN                              12.15         Cable
# 3                28  Offer C                               4.89   Fiber Optic
# 4                49      NaN                              44.33   Fiber Optic
#
#    Avg Monthly GB Download Device Protection Plan Premium Tech Support  \
# 0                       21                     No                   No
# 1                       51                     No                   No
# 2                       26                    Yes                   No
# 3                       47                    Yes                  Yes
# 4                       11                    Yes                   No
#
#   Streaming Music Unlimited Data  Monthly Charge  Total Refunds  \
# 0              No            Yes           53.85            0.0
# 1              No            Yes           70.70            0.0
# 2             Yes            Yes           99.65            0.0
# 3             Yes            Yes          104.80            0.0
# 4             Yes            Yes          103.70            0.0
#
#    Total Extra Data Charges  Total Long Distance Charges  Total Revenue
# 0                         0                        20.94         129.09
# 1                         0                        18.24         169.89
# 2                         0                        97.20         917.70
# 3                         0                       136.92        3182.97
# 4                         0                      2172.17        7208.47

# %% [markdown]
# ## Cleaning data

# %%
# Lowercasing and adding _ between spaces

# %%
def snakecase_columns(df: pd.DataFrame) -> pd.DataFrame:
    
    snakecase_cols = []

    for col in df.columns:
        col = col.lower().replace(' ', '_')
        col = col.replace('neighborhood', 'neighbourhood')
        snakecase_cols.append(col)

    df.columns = snakecase_cols

    return df

# %%
snakecase_columns(data)
# Out:
#       customerid  count        country       state          city  zip_code  \
# 0     3668-QPYBK      1  United States  California   Los Angeles     90003
# 1     9237-HQITU      1  United States  California   Los Angeles     90005
# 2     9305-CDSKC      1  United States  California   Los Angeles     90006
# 3     7892-POOKP      1  United States  California   Los Angeles     90010
# 4     0280-XJGEX      1  United States  California   Los Angeles     90015
# ...          ...    ...            ...         ...           ...       ...
# 7038  2569-WGERO      1  United States  California       Landers     92285
# 7039  6840-RESVB      1  United States  California      Adelanto     92301
# 7040  2234-XADUH      1  United States  California         Amboy     92304
# 7041  4801-JZAZL      1  United States  California  Angelus Oaks     92305
# 7042  3186-AJIEK      1  United States  California  Apple Valley     92308
#
#                     lat_long   latitude   longitude  gender senior_citizen  \
# 0     33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1      34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2     34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3     34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4     34.039224, -118.266293  34.039224 -118.266293    Male             No
# ...                      ...        ...         ...     ...            ...
# 7038  34.341737, -116.539416  34.341737 -116.539416  Female             No
# 7039  34.667815, -117.536183  34.667815 -117.536183    Male             No
# 7040  34.559882, -115.637164  34.559882 -115.637164  Female             No
# 7041     34.1678, -116.86433  34.167800 -116.864330  Female             No
# 7042  34.424926, -117.184503  34.424926 -117.184503    Male             No
#
#      partner dependents  tenure_months phone_service    multiple_lines  \
# 0         No         No              2           Yes                No
# 1         No        Yes              2           Yes                No
# 2         No        Yes              8           Yes               Yes
# 3        Yes        Yes             28           Yes               Yes
# 4         No        Yes             49           Yes               Yes
# ...      ...        ...            ...           ...               ...
# 7038      No         No             72           Yes                No
# 7039     Yes        Yes             24           Yes               Yes
# 7040     Yes        Yes             72           Yes               Yes
# 7041     Yes        Yes             11            No  No phone service
# 7042      No         No             66           Yes                No
#
#      internet_service      online_security        online_backup  \
# 0                 DSL                  Yes                  Yes
# 1         Fiber optic                   No                   No
# 2         Fiber optic                   No                   No
# 3         Fiber optic                   No                   No
# 4         Fiber optic                   No                  Yes
# ...               ...                  ...                  ...
# 7038               No  No internet service  No internet service
# 7039              DSL                  Yes                   No
# 7040      Fiber optic                   No                  Yes
# 7041              DSL                  Yes                   No
# 7042      Fiber optic                  Yes                   No
#
#         device_protection         tech_support         streaming_tv  \
# 0                      No                   No                   No
# 1                      No                   No                   No
# 2                     Yes                   No                  Yes
# 3                     Yes                  Yes                  Yes
# 4                     Yes                   No                  Yes
# ...                   ...                  ...                  ...
# 7038  No internet service  No internet service  No internet service
# 7039                  Yes                  Yes                  Yes
# 7040                  Yes                   No                  Yes
# 7041                   No                   No                   No
# 7042                  Yes                  Yes                  Yes
#
#          streaming_movies        contract paperless_billing  \
# 0                      No  Month-to-month               Yes
# 1                      No  Month-to-month               Yes
# 2                     Yes  Month-to-month               Yes
# 3                     Yes  Month-to-month               Yes
# 4                     Yes  Month-to-month               Yes
# ...                   ...             ...               ...
# 7038  No internet service        Two year               Yes
# 7039                  Yes        One year               Yes
# 7040                  Yes        One year               Yes
# 7041                   No  Month-to-month               Yes
# 7042                  Yes        Two year               Yes
#
#                  payment_method  monthly_charges total_charges churn_label  \
# 0                  Mailed check            53.85        108.15         Yes
# 1              Electronic check            70.70        151.65         Yes
# 2              Electronic check            99.65         820.5         Yes
# 3              Electronic check           104.80       3046.05         Yes
# 4     Bank transfer (automatic)           103.70        5036.3         Yes
# ...                         ...              ...           ...         ...
# 7038  Bank transfer (automatic)            21.15        1419.4          No
# 7039               Mailed check            84.80        1990.5          No
# 7040    Credit card (automatic)           103.20        7362.9          No
# 7041           Electronic check            29.60        346.45          No
# 7042  Bank transfer (automatic)           105.65        6844.5          No
#
#       churn_value  churn_score  cltv                   churn_reason  age  \
# 0               1           86  3239   Competitor made better offer   37
# 1               1           67  2701                          Moved   19
# 2               1           86  5372                          Moved   31
# 3               1           84  5003                          Moved   23
# 4               1           89  5340  Competitor had better devices   38
# ...           ...          ...   ...                            ...  ...
# 7038            0           45  5306                            NaN   30
# 7039            0           59  2140                            NaN   38
# 7040            0           71  5560                            NaN   30
# 7041            0           59  2793                            NaN   32
# 7042            0           38  5097                            NaN   44
#
#      under_30 married  number_of_dependents  satisfaction_score  \
# 0          No      No                     0                   1
# 1         Yes      No                     2                   2
# 2          No      No                     2                   3
# 3         Yes     Yes                     3                   3
# 4          No      No                     1                   1
# ...       ...     ...                   ...                 ...
# 7038       No      No                     0                   5
# 7039       No     Yes                     2                   3
# 7040       No     Yes                     2                   4
# 7041       No     Yes                     2                   4
# 7042       No      No                     0                   4
#
#      customer_status quarter referred_a_friend  number_of_referrals  \
# 0            Churned      Q3                No                    0
# 1            Churned      Q3                No                    0
# 2            Churned      Q3                No                    0
# 3            Churned      Q3                No                    0
# 4            Churned      Q3                No                    0
# ...              ...     ...               ...                  ...
# 7038          Stayed      Q3                No                    0
# 7039          Stayed      Q3               Yes                    1
# 7040          Stayed      Q3               Yes                    4
# 7041          Stayed      Q3               Yes                    1
# 7042          Stayed      Q3                No                    0
#
#       tenure_in_months    offer  avg_monthly_long_distance_charges  \
# 0                    2      NaN                              10.47
# 1                    2      NaN                               9.12
# 2                    8      NaN                              12.15
# 3                   28  Offer C                               4.89
# 4                   49      NaN                              44.33
# ...                ...      ...                                ...
# 7038                72      NaN                              22.77
# 7039                24  Offer C                              36.05
# 7040                72      NaN                              29.66
# 7041                11      NaN                               0.00
# 7042                66      NaN                              30.96
#
#      internet_type  avg_monthly_gb_download device_protection_plan  \
# 0              DSL                       21                     No
# 1      Fiber Optic                       51                     No
# 2            Cable                       26                    Yes
# 3      Fiber Optic                       47                    Yes
# 4      Fiber Optic                       11                    Yes
# ...            ...                      ...                    ...
# 7038           NaN                        0                     No
# 7039         Cable                       24                    Yes
# 7040   Fiber Optic                       59                    Yes
# 7041           DSL                       17                     No
# 7042   Fiber Optic                       11                    Yes
#
#      premium_tech_support streaming_music unlimited_data  monthly_charge  \
# 0                      No              No            Yes           53.85
# 1                      No              No            Yes           70.70
# 2                      No             Yes            Yes           99.65
# 3                     Yes             Yes            Yes          104.80
# 4                      No             Yes            Yes          103.70
# ...                   ...             ...            ...             ...
# 7038                   No              No             No           21.15
# 7039                  Yes             Yes            Yes           84.80
# 7040                   No             Yes            Yes          103.20
# 7041                   No              No            Yes           29.60
# 7042                  Yes             Yes            Yes          105.65
#
#       total_refunds  total_extra_data_charges  total_long_distance_charges  \
# 0              0.00                         0                        20.94
# 1              0.00                         0                        18.24
# 2              0.00                         0                        97.20
# 3              0.00                         0                       136.92
# 4              0.00                         0                      2172.17
# ...             ...                       ...                          ...
# 7038          19.31                         0                      1639.44
# 7039          48.23                         0                       865.20
# 7040          45.38                         0                      2135.52
# 7041          27.24                         0                         0.00
# 7042           0.00                         0                      2043.36
#
#       total_revenue
# 0            129.09
# 1            169.89
# 2            917.70
# 3           3182.97
# 4           7208.47
# ...             ...
# 7038        3039.53
# 7039        2807.47
# 7040        9453.04
# 7041         319.21
# 7042        8887.86
#
# [7043 rows x 56 columns]

# %%
#Checking unique values of columns, to decide if they have data worth keeping for the models.

print(data['country'].unique())
print(data['state'].unique())
print(data['city'].unique())
print(data['partner'].unique())
# Out:
# ['United States']
# ['California']
# ['Los Angeles' 'Beverly Hills' 'Huntington Park' ... 'Standish' 'Tulelake'
#  'Olympic Valley']
# ['No' 'Yes']

# %% [markdown]
# ### Missing Values

# %%
# Checking missing values

nulls_percent_df = pd.DataFrame(data.isna().sum()/len(data)).reset_index()
nulls_percent_df.columns = ['column_name', 'nulls_percentage']
nulls_percent_df
# Out:
#                           column_name  nulls_percentage
# 0                          customerid          0.000000
# 1                               count          0.000000
# 2                             country          0.000000
# 3                               state          0.000000
# 4                                city          0.000000
# 5                            zip_code          0.000000
# 6                            lat_long          0.000000
# 7                            latitude          0.000000
# 8                           longitude          0.000000
# 9                              gender          0.000000
# 10                     senior_citizen          0.000000
# 11                            partner          0.000000
# 12                         dependents          0.000000
# 13                      tenure_months          0.000000
# 14                      phone_service          0.000000
# 15                     multiple_lines          0.000000
# 16                   internet_service          0.000000
# 17                    online_security          0.000000
# 18                      online_backup          0.000000
# 19                  device_protection          0.000000
# 20                       tech_support          0.000000
# 21                       streaming_tv          0.000000
# 22                   streaming_movies          0.000000
# 23                           contract          0.000000
# 24                  paperless_billing          0.000000
# 25                     payment_method          0.000000
# 26                    monthly_charges          0.000000
# 27                      total_charges          0.000000
# 28                        churn_label          0.000000
# 29                        churn_value          0.000000
# 30                        churn_score          0.000000
# 31                               cltv          0.000000
# 32                       churn_reason          0.734630
# 33                                age          0.000000
# 34                           under_30          0.000000
# 35                            married          0.000000
# 36               number_of_dependents          0.000000
# 37                 satisfaction_score          0.000000
# 38                    customer_status          0.000000
# 39                            quarter          0.000000
# 40                  referred_a_friend          0.000000
# 41                number_of_referrals          0.000000
# 42                   tenure_in_months          0.000000
# 43                              offer          0.550476
# 44  avg_monthly_long_distance_charges          0.000000
# 45                      internet_type          0.216669
# 46            avg_monthly_gb_download          0.000000
# 47             device_protection_plan          0.000000
# 48               premium_tech_support          0.000000
# 49                    streaming_music          0.000000
# 50                     unlimited_data          0.000000
# 51                     monthly_charge          0.000000
# 52                      total_refunds          0.000000
# 53           total_extra_data_charges          0.000000
# 54        total_long_distance_charges          0.000000
# 55                      total_revenue          0.000000

# %%
nulls_percent_df[nulls_percent_df['nulls_percentage']!=0]
# Out:
#       column_name  nulls_percentage
# 32   churn_reason          0.734630
# 43          offer          0.550476
# 45  internet_type          0.216669

# %%
columns_above_threshold = nulls_percent_df[nulls_percent_df['nulls_percentage']>0.25]
columns_above_threshold['column_name']
# Out:
# 32    churn_reason
# 43           offer
# Name: column_name, dtype: object

# %%
# Dropping Offer Column, the description of the database just mentions Offer_A, Offer_B, etc, with no additional information about the Offer. We will drop it for now and check the model performance (so as to asses if potentially would be needed or not)
# churn_reason should be dropped as well, but I will drop it after with all the churn related fields

data = data.drop('offer', axis=1)
data.isna().sum()
# Out:
# customerid                              0
# count                                   0
# country                                 0
# state                                   0
# city                                    0
# zip_code                                0
# lat_long                                0
# latitude                                0
# longitude                               0
# gender                                  0
# senior_citizen                          0
# partner                                 0
# dependents                              0
# tenure_months                           0
# phone_service                           0
# multiple_lines                          0
# internet_service                        0
# online_security                         0
# online_backup                           0
# device_protection                       0
# tech_support                            0
# streaming_tv                            0
# streaming_movies                        0
# contract                                0
# paperless_billing                       0
# payment_method                          0
# monthly_charges                         0
# total_charges                           0
# churn_label                             0
# churn_value                             0
# churn_score                             0
# cltv                                    0
# churn_reason                         5174
# age                                     0
# under_30                                0
# married                                 0
# number_of_dependents                    0
# satisfaction_score                      0
# customer_status                         0
# quarter                                 0
# referred_a_friend                       0
# number_of_referrals                     0
# tenure_in_months                        0
# avg_monthly_long_distance_charges       0
# internet_type                        1526
# avg_monthly_gb_download                 0
# device_protection_plan                  0
# premium_tech_support                    0
# streaming_music                         0
# unlimited_data                          0
# monthly_charge                          0
# total_refunds                           0
# total_extra_data_charges                0
# total_long_distance_charges             0
# total_revenue                           0
# dtype: int64

# %%
# Since 20% seems too much data to "fake" I will drop these rows, although they seem
# they would have a correlation with Churn. I will drop the rows to check correaltion matrix

data = data.dropna(subset=['internet_type'])
data.isna().sum()
# Out:
# customerid                              0
# count                                   0
# country                                 0
# state                                   0
# city                                    0
# zip_code                                0
# lat_long                                0
# latitude                                0
# longitude                               0
# gender                                  0
# senior_citizen                          0
# partner                                 0
# dependents                              0
# tenure_months                           0
# phone_service                           0
# multiple_lines                          0
# internet_service                        0
# online_security                         0
# online_backup                           0
# device_protection                       0
# tech_support                            0
# streaming_tv                            0
# streaming_movies                        0
# contract                                0
# paperless_billing                       0
# payment_method                          0
# monthly_charges                         0
# total_charges                           0
# churn_label                             0
# churn_value                             0
# churn_score                             0
# cltv                                    0
# churn_reason                         3761
# age                                     0
# under_30                                0
# married                                 0
# number_of_dependents                    0
# satisfaction_score                      0
# customer_status                         0
# quarter                                 0
# referred_a_friend                       0
# number_of_referrals                     0
# tenure_in_months                        0
# avg_monthly_long_distance_charges       0
# internet_type                           0
# avg_monthly_gb_download                 0
# device_protection_plan                  0
# premium_tech_support                    0
# streaming_music                         0
# unlimited_data                          0
# monthly_charge                          0
# total_refunds                           0
# total_extra_data_charges                0
# total_long_distance_charges             0
# total_revenue                           0
# dtype: int64

# %%
#I found out that total_charges couldnt be converted to float, so im exploring it and I find there are 11 blank spaces

data['total_charges'].value_counts()
# Out:
# total_charges
# 45.3       6
#            5
# 69.65      4
# 74.7       4
# 69.95      4
#           ..
# 1406       1
# 1373.05    1
# 2878.55    1
# 3959.15    1
# 6844.5     1
# Name: count, Length: 5259, dtype: int64

# %%
#I filter the blank spaces

filtered_df = data[data['total_charges'].str.contains(r'\s', na=False)]

# %%
filtered_df.shape
# Out:
# (5, 55)

# %%
rows_to_drop = filtered_df.index

# %%
#Drop blank spaces in total_charges

data = data.drop(rows_to_drop)

# %% [markdown]
# ### Changing Datatypes

# %%
#Changing data types

data['total_charges'] = data['total_charges'].astype('float64')
data['satisfaction_score'] = data['satisfaction_score'].astype('object')

# %%
data.shape
# Out:
# (5512, 55)

# %% [markdown]
# ### Saving the original dataset

# %%
#Saving original dataset in a new df

full_data = data.copy()

# %% [markdown]
# ### Dropping columns

# %%
# Dropping columns that have no valuable information for the model or are duplicated columns (with a similar but different name)

columns_to_drop = ['customerid','country','state','zip_code','lat_long','latitude','longitude','quarter','count','age','city','internet_service','device_protection_plan','tech_support', 'tenure_months', 'monthly_charges', 'partner']

data = data.drop(columns_to_drop, axis=1)

# %%
data.head()
# Out:
#    gender senior_citizen dependents phone_service multiple_lines  \
# 0    Male             No         No           Yes             No
# 1  Female             No        Yes           Yes             No
# 2  Female             No        Yes           Yes            Yes
# 3  Female             No        Yes           Yes            Yes
# 4    Male             No        Yes           Yes            Yes
#
#   online_security online_backup device_protection streaming_tv  \
# 0             Yes           Yes                No           No
# 1              No            No                No           No
# 2              No            No               Yes          Yes
# 3              No            No               Yes          Yes
# 4              No           Yes               Yes          Yes
#
#   streaming_movies        contract paperless_billing  \
# 0               No  Month-to-month               Yes
# 1               No  Month-to-month               Yes
# 2              Yes  Month-to-month               Yes
# 3              Yes  Month-to-month               Yes
# 4              Yes  Month-to-month               Yes
#
#               payment_method  total_charges churn_label  churn_value  \
# 0               Mailed check         108.15         Yes            1
# 1           Electronic check         151.65         Yes            1
# 2           Electronic check         820.50         Yes            1
# 3           Electronic check        3046.05         Yes            1
# 4  Bank transfer (automatic)        5036.30         Yes            1
#
#    churn_score  cltv                   churn_reason under_30 married  \
# 0           86  3239   Competitor made better offer       No      No
# 1           67  2701                          Moved      Yes      No
# 2           86  5372                          Moved       No      No
# 3           84  5003                          Moved      Yes     Yes
# 4           89  5340  Competitor had better devices       No      No
#
#    number_of_dependents satisfaction_score customer_status referred_a_friend  \
# 0                     0                  1         Churned                No
# 1                     2                  2         Churned                No
# 2                     2                  3         Churned                No
# 3                     3                  3         Churned                No
# 4                     1                  1         Churned                No
#
#    number_of_referrals  tenure_in_months  avg_monthly_long_distance_charges  \
# 0                    0                 2                              10.47
# 1                    0                 2                               9.12
# 2                    0                 8                              12.15
# 3                    0                28                               4.89
# 4                    0                49                              44.33
#
#   internet_type  avg_monthly_gb_download premium_tech_support streaming_music  \
# 0           DSL                       21                   No              No
# 1   Fiber Optic                       51                   No              No
# 2         Cable                       26                   No             Yes
# 3   Fiber Optic                       47                  Yes             Yes
# 4   Fiber Optic                       11                   No             Yes
#
#   unlimited_data  monthly_charge  total_refunds  total_extra_data_charges  \
# 0            Yes           53.85            0.0                         0
# 1            Yes           70.70            0.0                         0
# 2            Yes           99.65            0.0                         0
# 3            Yes          104.80            0.0                         0
# 4            Yes          103.70            0.0                         0
#
#    total_long_distance_charges  total_revenue
# 0                        20.94         129.09
# 1                        18.24         169.89
# 2                        97.20         917.70
# 3                       136.92        3182.97
# 4                      2172.17        7208.47

# %%
#Dropping columns of related to churn (just keeping y = churn_value)

columns_to_drop_churn = ['churn_label','churn_score','churn_reason','customer_status', 'churn_reason']
data = data.drop(columns_to_drop_churn, axis=1)
data.head()
# Out:
#    gender senior_citizen dependents phone_service multiple_lines  \
# 0    Male             No         No           Yes             No
# 1  Female             No        Yes           Yes             No
# 2  Female             No        Yes           Yes            Yes
# 3  Female             No        Yes           Yes            Yes
# 4    Male             No        Yes           Yes            Yes
#
#   online_security online_backup device_protection streaming_tv  \
# 0             Yes           Yes                No           No
# 1              No            No                No           No
# 2              No            No               Yes          Yes
# 3              No            No               Yes          Yes
# 4              No           Yes               Yes          Yes
#
#   streaming_movies        contract paperless_billing  \
# 0               No  Month-to-month               Yes
# 1               No  Month-to-month               Yes
# 2              Yes  Month-to-month               Yes
# 3              Yes  Month-to-month               Yes
# 4              Yes  Month-to-month               Yes
#
#               payment_method  total_charges  churn_value  cltv under_30  \
# 0               Mailed check         108.15            1  3239       No
# 1           Electronic check         151.65            1  2701      Yes
# 2           Electronic check         820.50            1  5372       No
# 3           Electronic check        3046.05            1  5003      Yes
# 4  Bank transfer (automatic)        5036.30            1  5340       No
#
#   married  number_of_dependents satisfaction_score referred_a_friend  \
# 0      No                     0                  1                No
# 1      No                     2                  2                No
# 2      No                     2                  3                No
# 3     Yes                     3                  3                No
# 4      No                     1                  1                No
#
#    number_of_referrals  tenure_in_months  avg_monthly_long_distance_charges  \
# 0                    0                 2                              10.47
# 1                    0                 2                               9.12
# 2                    0                 8                              12.15
# 3                    0                28                               4.89
# 4                    0                49                              44.33
#
#   internet_type  avg_monthly_gb_download premium_tech_support streaming_music  \
# 0           DSL                       21                   No              No
# 1   Fiber Optic                       51                   No              No
# 2         Cable                       26                   No             Yes
# 3   Fiber Optic                       47                  Yes             Yes
# 4   Fiber Optic                       11                   No             Yes
#
#   unlimited_data  monthly_charge  total_refunds  total_extra_data_charges  \
# 0            Yes           53.85            0.0                         0
# 1            Yes           70.70            0.0                         0
# 2            Yes           99.65            0.0                         0
# 3            Yes          104.80            0.0                         0
# 4            Yes          103.70            0.0                         0
#
#    total_long_distance_charges  total_revenue
# 0                        20.94         129.09
# 1                        18.24         169.89
# 2                        97.20         917.70
# 3                       136.92        3182.97
# 4                      2172.17        7208.47

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5512 entries, 0 to 7042
# Data columns (total 34 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             5512 non-null   object
#  1   senior_citizen                     5512 non-null   object
#  2   dependents                         5512 non-null   object
#  3   phone_service                      5512 non-null   object
#  4   multiple_lines                     5512 non-null   object
#  5   online_security                    5512 non-null   object
#  6   online_backup                      5512 non-null   object
#  7   device_protection                  5512 non-null   object
#  8   streaming_tv                       5512 non-null   object
#  9   streaming_movies                   5512 non-null   object
#  10  contract                           5512 non-null   object
#  11  paperless_billing                  5512 non-null   object
#  12  payment_method                     5512 non-null   object
#  13  total_charges                      5512 non-null   float64
#  14  churn_value                        5512 non-null   int64
#  15  cltv                               5512 non-null   int64
#  16  under_30                           5512 non-null   object
#  17  married                            5512 non-null   object
#  18  number_of_dependents               5512 non-null   int64
#  19  satisfaction_score                 5512 non-null   object
#  20  referred_a_friend                  5512 non-null   object
#  21  number_of_referrals                5512 non-null   int64
#  22  tenure_in_months                   5512 non-null   int64
#  23  avg_monthly_long_distance_charges  5512 non-null   float64
#  24  internet_type                      5512 non-null   object
#  25  avg_monthly_gb_download            5512 non-null   int64
#  26  premium_tech_support               5512 non-null   object
#  27  streaming_music                    5512 non-null   object
#  28  unlimited_data                     5512 non-null   object
#  29  monthly_charge                     5512 non-null   float64
#  30  total_refunds                      5512 non-null   float64
#  31  total_extra_data_charges           5512 non-null   int64
#  32  total_long_distance_charges        5512 non-null   float64
#  33  total_revenue                      5512 non-null   float64
# dtypes: float64(6), int64(7), object(21)
# memory usage: 1.5+ MB

# %%
data.isna().sum()
# Out:
# gender                               0
# senior_citizen                       0
# dependents                           0
# phone_service                        0
# multiple_lines                       0
# online_security                      0
# online_backup                        0
# device_protection                    0
# streaming_tv                         0
# streaming_movies                     0
# contract                             0
# paperless_billing                    0
# payment_method                       0
# total_charges                        0
# churn_value                          0
# cltv                                 0
# under_30                             0
# married                              0
# number_of_dependents                 0
# satisfaction_score                   0
# referred_a_friend                    0
# number_of_referrals                  0
# tenure_in_months                     0
# avg_monthly_long_distance_charges    0
# internet_type                        0
# avg_monthly_gb_download              0
# premium_tech_support                 0
# streaming_music                      0
# unlimited_data                       0
# monthly_charge                       0
# total_refunds                        0
# total_extra_data_charges             0
# total_long_distance_charges          0
# total_revenue                        0
# dtype: int64

# %% [markdown]
# ## Saving to csv files

# %%
# Exporting cleaned dataset to a csv file

full_data.to_csv('../data/cleaned/full_data.csv', index=False)
data.to_csv('../data/cleaned/data.csv', index=False)
